# %%
import numpy as np

# %%
A = np.array ([1,2,3,4,5])

# %% [markdown]
# # mean = sum of element / no of element

# %%
A.mean ()
# Out:
# np.float64(3.0)

# %%
(1 + 2 + 3 + 4 + 5 ) / 5
# Out:
# 3.0

# %% [markdown]
# # std = standard deviation

# %%
A.std ()
# Out:
# np.float64(1.4142135623730951)

# %% [markdown]
# # var = varience

# %%
A.var()
# Out:
# np.float64(2.0)

# %% [markdown]
# # min

# %%
A.min ()
# Out:
# np.int64(1)

# %% [markdown]
# # max

# %%
A.max ()
# Out:
# np.int64(5)

# %% [markdown]
# # sum

# %%
A.sum ()
# Out:
# np.int64(15)

# %% [markdown]
# # prod

# %%
A.prod ()
# Out:
# np.int64(120)

# %% [markdown]
# # median

# %%
np.median (A)
# Out:
# np.float64(3.0)

# %% [markdown]
# # percentile

# %%
np.percentile ( A , 50 )
# Out:
# np.float64(3.0)

# %% [markdown]
# # argmin = return min value index

# %%
np.argmin (A)
# Out:
# np.int64(0)

# %% [markdown]
# # argmax

# %%
np .argmax (A)
# Out:
# np.int64(4)

# %% [markdown]
# # np.corrcoef() – Compute the correlation coefficient matrix of two arrays.

# %%
np.corrcoef (A)
# Out:
# np.float64(1.0)

# %% [markdown]
# # np.unique() – Find the unique elements of an array.

# %%
np.unique (A)
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# # np.diff() – Compute the n-th differences of an array.

# %%
np.diff (A)
# Out:
# array([1, 1, 1, 1])

# %% [markdown]
# # np.cumsum() – Compute the cumulative sum of an array.

# %%
np.cumsum (A)
# Out:
# array([ 1,  3,  6, 10, 15])

# %% [markdown]
# # np.linspace() – Create an array with evenly spaced numbers over a specified interval.

# %%
np.linspace (0 , 10 , 5, dtype = 'int64')
# Out:
# array([ 0,  2,  5,  7, 10])

# %% [markdown]
# # np.exp() – Compute the exponential of an array.

# %%
np.exp (A).astype ('int64')
# Out:
# array([  2,   7,  20,  54, 148])
