# %% [markdown]
# # Vectorization

# %%
import numpy as np

# %%
A = np.array ([1,2,3])

A = A + 5

print (A)
# Out:
# [6 7 8]

# %% [markdown]
# # Broadcasting

# %%
A1 = np.array ([1,2,3])

A2 = np.array ([4,5,6])

A3 = A1 + A2 

A3
# Out:
# array([5, 7, 9])

# %%
print (A1) 

A1 = A1 + [10,10,10] 
# A1 = A1 + 10

A1
# Out:
# [1 2 3]
# array([11, 12, 13])

# %%
N1 = np.array ([[10,20,30] , [40,50,60]])
N2 = np.array ([1,2,3]) 

N3 = N1 + N2

print (N3)
# Out:
# [[11 22 33]
#  [41 52 63]]
