# %%
import pandas as pd

# %%
S = pd.Series ([71,84,75,99,91]) 
type (S)
# Out:
# pandas.core.series.Series

# %%
print (S)
# Out:
# 0    71
# 1    84
# 2    75
# 3    99
# 4    91
# dtype: int64

# %% [markdown]
# # costom index to Series

# %%
S1 = pd.Series ([71,84,85,93,99] , index = ["Ramesh" , 'Ganesh' , 'Suresh','Mahesh','Sushil'])
S1
# Out:
# Ramesh    71
# Ganesh    84
# Suresh    85
# Mahesh    93
# Sushil    99
# dtype: int64
