# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# # 1 Series

# %%
S = pd.Series ([71,84,75,99,96]) 
type (S)
# Out:
# pandas.core.series.Series

# %%
print (S)
# Out:
# 0    71
# 1    84
# 2    75
# 3    99
# 4    96
# dtype: int64

# %% [markdown]
# # costom index to Series

# %%
S1 = pd.Series ([71,84,85,93,99] , index = ["Ramesh" , 'Ganesh' , 'Suresh','Mahesh','Sushil'])
S1
# Out:
# Ramesh    71
# Ganesh    84
# Suresh    85
# Mahesh    93
# Sushil    99
# dtype: int64

# %% [markdown]
# # Data Frames

# %%
Data = {
    "name" : ["Sushil" , "Sahiil" , "Samir" ],
    "age": [20,21,22] ,
    "city" : ["parbhani" ,"pune" , "delhi"]
}

# %%
df = pd.DataFrame (Data)

# %%
df
# Out:
#      name  age      city
# 0  Sushil   20  parbhani
# 1  Sahiil   21      pune
# 2   Samir   22     delhi

# %% [markdown]
# # index and column

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')
