# %% [markdown]
# # Data Transformation

# %% [markdown]
# Once Data chean then reshape , reformat and reordered .

# %%
import pandas as pd

# %%
Data = pd.read_csv ("Movie.csv")

# %%
Data.columns = Data.columns.str.strip () 

Data
# Out:
#              Actor                Film  Year            Gener  \
# 0    shak ruk khan              Pathan  2023          Action
# 1      salmankhan     Tiger zindya he   2017          Action
# 2       Amir khan               Dangal  2016       Biological
# 3    Ranvir kapoor              Animan  2022         Fantasy
# 4  Ayushman kurana            Padmawat  2018      Historical
# 5   Rajkummar rao                Stree  2018           Horror
# 6    Hritik Roshan                 War  2019          Action
# 7     Akshay Kumar          Good Newaz  2019          Comedy
# 8    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 9       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
#
#    Box Office (NR Cross)  IMDB
# 0                   1050   7.2
# 1                    565   8.0
# 2                   2024   9.2
# 3                    431   9.0
# 4                    585   8.0
# 5                    111   8.2
# 6                    180   7.6
# 7                    318   6.7
# ...

# %%
Data.sort_values ("Year")
# Out:
#              Actor                Film  Year            Gener  \
# 2       Amir khan               Dangal  2016       Biological
# 1      salmankhan     Tiger zindya he   2017          Action
# 9       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 4  Ayushman kurana            Padmawat  2018      Historical
# 5   Rajkummar rao                Stree  2018           Horror
# 6    Hritik Roshan                 War  2019          Action
# 7     Akshay Kumar          Good Newaz  2019          Comedy
# 3    Ranvir kapoor              Animan  2022         Fantasy
# 8    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 0    shak ruk khan              Pathan  2023          Action
#
#    Box Office (NR Cross)  IMDB
# 2                   2024   9.2
# 1                    565   8.0
# 9                    201   4.8
# 4                    585   8.0
# 5                    111   8.2
# 6                    180   7.6
# 7                    318   6.7
# 3                    431   9.0
# ...

# %%
Data.sort_values ("Year" ,ascending = False)
# Out:
#              Actor                Film  Year            Gener  \
# 0    shak ruk khan              Pathan  2023          Action
# 3    Ranvir kapoor              Animan  2022         Fantasy
# 8    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 6    Hritik Roshan                 War  2019          Action
# 7     Akshay Kumar          Good Newaz  2019          Comedy
# 4  Ayushman kurana            Padmawat  2018      Historical
# 5   Rajkummar rao                Stree  2018           Horror
# 1      salmankhan     Tiger zindya he   2017          Action
# 9       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 2       Amir khan               Dangal  2016       Biological
#
#    Box Office (NR Cross)  IMDB
# 0                   1050   7.2
# 3                    431   9.0
# 8                    166   7.7
# 6                    180   7.6
# 7                    318   6.7
# 4                    585   8.0
# 5                    111   8.2
# 1                    565   8.0
# ...

# %%
D2 = Data.sort_values (["Year" , "IMDB"]).copy ()   
D2
# Out:
#              Actor                Film  Year            Gener  \
# 2       Amir khan               Dangal  2016       Biological
# 9       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 1      salmankhan     Tiger zindya he   2017          Action
# 4  Ayushman kurana            Padmawat  2018      Historical
# 5   Rajkummar rao                Stree  2018           Horror
# 7     Akshay Kumar          Good Newaz  2019          Comedy
# 6    Hritik Roshan                 War  2019          Action
# 8    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 3    Ranvir kapoor              Animan  2022         Fantasy
# 0    shak ruk khan              Pathan  2023          Action
#
#    Box Office (NR Cross)  IMDB
# 2                   2024   9.2
# 9                    201   4.8
# 1                    565   8.0
# 4                    585   8.0
# 5                    111   8.2
# 7                    318   6.7
# 6                    180   7.6
# 8                    166   7.7
# ...

# %% [markdown]
# # reordering

# %%
D2
# Out:
#              Actor                Film  Year            Gener  \
# 2       Amir khan               Dangal  2016       Biological
# 9       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 1      salmankhan     Tiger zindya he   2017          Action
# 4  Ayushman kurana            Padmawat  2018      Historical
# 5   Rajkummar rao                Stree  2018           Horror
# 7     Akshay Kumar          Good Newaz  2019          Comedy
# 6    Hritik Roshan                 War  2019          Action
# 8    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 3    Ranvir kapoor              Animan  2022         Fantasy
# 0    shak ruk khan              Pathan  2023          Action
#
#    Box Office (NR Cross)  IMDB
# 2                   2024   9.2
# 9                    201   4.8
# 1                    565   8.0
# 4                    585   8.0
# 5                    111   8.2
# 7                    318   6.7
# 6                    180   7.6
# 8                    166   7.7
# ...

# %%
D2.reset_index () # Return a copy
# Out:
#    index            Actor                Film  Year            Gener  \
# 0      2       Amir khan               Dangal  2016       Biological
# 1      9       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 2      1      salmankhan     Tiger zindya he   2017          Action
# 3      4  Ayushman kurana            Padmawat  2018      Historical
# 4      5   Rajkummar rao                Stree  2018           Horror
# 5      7     Akshay Kumar          Good Newaz  2019          Comedy
# 6      6    Hritik Roshan                 War  2019          Action
# 7      8    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 8      3    Ranvir kapoor              Animan  2022         Fantasy
# 9      0    shak ruk khan              Pathan  2023          Action
#
#    Box Office (NR Cross)  IMDB
# 0                   2024   9.2
# 1                    201   4.8
# 2                    565   8.0
# 3                    585   8.0
# 4                    111   8.2
# ...

# %%
D2.reset_index (drop=True)  # drop index column
# Out:
#              Actor                Film  Year            Gener  \
# 0       Amir khan               Dangal  2016       Biological
# 1       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 2      salmankhan     Tiger zindya he   2017          Action
# 3  Ayushman kurana            Padmawat  2018      Historical
# 4   Rajkummar rao                Stree  2018           Horror
# 5     Akshay Kumar          Good Newaz  2019          Comedy
# 6    Hritik Roshan                 War  2019          Action
# 7    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 8    Ranvir kapoor              Animan  2022         Fantasy
# 9    shak ruk khan              Pathan  2023          Action
#
#    Box Office (NR Cross)  IMDB
# 0                   2024   9.2
# 1                    201   4.8
# 2                    565   8.0
# 3                    585   8.0
# 4                    111   8.2
# 5                    318   6.7
# 6                    180   7.6
# 7                    166   7.7
# ...

# %%
D2.reset_index ( drop=True , inplace=True) # Change original D2 |

# %%
D2
# Out:
#              Actor                Film  Year            Gener  \
# 0       Amir khan               Dangal  2016       Biological
# 1       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 2      salmankhan     Tiger zindya he   2017          Action
# 3  Ayushman kurana            Padmawat  2018      Historical
# 4   Rajkummar rao                Stree  2018           Horror
# 5     Akshay Kumar          Good Newaz  2019          Comedy
# 6    Hritik Roshan                 War  2019          Action
# 7    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 8    Ranvir kapoor              Animan  2022         Fantasy
# 9    shak ruk khan              Pathan  2023          Action
#
#    Box Office (NR Cross)  IMDB
# 0                   2024   9.2
# 1                    201   4.8
# 2                    565   8.0
# 3                    585   8.0
# 4                    111   8.2
# 5                    318   6.7
# 6                    180   7.6
# 7                    166   7.7
# ...

# %%
D2.sort_index ()
# Out:
#              Actor                Film  Year            Gener  \
# 0       Amir khan               Dangal  2016       Biological
# 1       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 2      salmankhan     Tiger zindya he   2017          Action
# 3  Ayushman kurana            Padmawat  2018      Historical
# 4   Rajkummar rao                Stree  2018           Horror
# 5     Akshay Kumar          Good Newaz  2019          Comedy
# 6    Hritik Roshan                 War  2019          Action
# 7    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 8    Ranvir kapoor              Animan  2022         Fantasy
# 9    shak ruk khan              Pathan  2023          Action
#
#    Box Office (NR Cross)  IMDB
# 0                   2024   9.2
# 1                    201   4.8
# 2                    565   8.0
# 3                    585   8.0
# 4                    111   8.2
# 5                    318   6.7
# 6                    180   7.6
# 7                    166   7.7
# ...

# %% [markdown]
# # Ranking

# %%
D2["IMDB"].rank ()
# Out:
# 0    10.0
# 1     1.0
# 2     6.5
# 3     6.5
# 4     8.0
# 5     2.0
# 6     4.0
# 7     5.0
# 8     9.0
# 9     3.0
# Name: IMDB, dtype: float64

# %%
D2["Rank"] = D2["IMDB"].rank (ascending = False) # high value low Rank

# %%
D2["Rank"] = D2["IMDB"] .rank (ascending = False , method = "dense") # Same Rank to Same IMDB Score

# %%
D2
# Out:
#              Actor                Film  Year            Gener  \
# 0       Amir khan               Dangal  2016       Biological
# 1       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 2      salmankhan     Tiger zindya he   2017          Action
# 3  Ayushman kurana            Padmawat  2018      Historical
# 4   Rajkummar rao                Stree  2018           Horror
# 5     Akshay Kumar          Good Newaz  2019          Comedy
# 6    Hritik Roshan                 War  2019          Action
# 7    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 8    Ranvir kapoor              Animan  2022         Fantasy
# 9    shak ruk khan              Pathan  2023          Action
#
#    Box Office (NR Cross)  IMDB  Rank
# 0                   2024   9.2   1.0
# 1                    201   4.8   9.0
# 2                    565   8.0   4.0
# 3                    585   8.0   4.0
# 4                    111   8.2   3.0
# 5                    318   6.7   8.0
# ...

# %% [markdown]
# # rename column and row

# %%
D2
# Out:
#              Actor                Film  Year            Gener  \
# 0       Amir khan               Dangal  2016       Biological
# 1       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 2      salmankhan     Tiger zindya he   2017          Action
# 3  Ayushman kurana            Padmawat  2018      Historical
# 4   Rajkummar rao                Stree  2018           Horror
# 5     Akshay Kumar          Good Newaz  2019          Comedy
# 6    Hritik Roshan                 War  2019          Action
# 7    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 8    Ranvir kapoor              Animan  2022         Fantasy
# 9    shak ruk khan              Pathan  2023          Action
#
#    Box Office (NR Cross)  IMDB  Rank
# 0                   2024   9.2   1.0
# 1                    201   4.8   9.0
# 2                    565   8.0   4.0
# 3                    585   8.0   4.0
# 4                    111   8.2   3.0
# 5                    318   6.7   8.0
# ...

# %%
D2.rename (columns = {"Actor" : "Name"}) 
D2.rename (columns = {"Actor" : "Name"} , inplace = True)
D2
# Out:
#               Name                Film  Year            Gener  \
# 0       Amir khan               Dangal  2016       Biological
# 1       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 2      salmankhan     Tiger zindya he   2017          Action
# 3  Ayushman kurana            Padmawat  2018      Historical
# 4   Rajkummar rao                Stree  2018           Horror
# 5     Akshay Kumar          Good Newaz  2019          Comedy
# 6    Hritik Roshan                 War  2019          Action
# 7    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 8    Ranvir kapoor              Animan  2022         Fantasy
# 9    shak ruk khan              Pathan  2023          Action
#
#    Box Office (NR Cross)  IMDB  Rank
# 0                   2024   9.2   1.0
# 1                    201   4.8   9.0
# 2                    565   8.0   4.0
# 3                    585   8.0   4.0
# 4                    111   8.2   3.0
# 5                    318   6.7   8.0
# ...

# %%
D2.rename (index = {1:"Key 1", 2 : "Key 2"}  , inplace = True ) 
D2
# Out:
#                   Name                Film  Year            Gener  \
# 0           Amir khan               Dangal  2016       Biological
# Key 1       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# Key 2      salmankhan     Tiger zindya he   2017          Action
# 3      Ayushman kurana            Padmawat  2018      Historical
# 4       Rajkummar rao                Stree  2018           Horror
# 5         Akshay Kumar          Good Newaz  2019          Comedy
# 6        Hritik Roshan                 War  2019          Action
# 7        Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 8        Ranvir kapoor              Animan  2022         Fantasy
# 9        shak ruk khan              Pathan  2023          Action
#
#        Box Office (NR Cross)  IMDB  Rank
# 0                       2024   9.2   1.0
# Key 1                    201   4.8   9.0
# Key 2                    565   8.0   4.0
# 3                        585   8.0   4.0
# ...

# %% [markdown]
# # Rearranging Columns

# %%
D2 [["Name" , "Film" ,"Gener"]]
# Out:
#                   Name                Film            Gener
# 0           Amir khan               Dangal       Biological
# Key 1       VsrunDawan  Badhri ki dulaniya  Romantic comedy
# Key 2      salmankhan     Tiger zindya he           Action
# 3      Ayushman kurana            Padmawat      Historical
# 4       Rajkummar rao                Stree           Horror
# 5         Akshay Kumar          Good Newaz          Comedy
# 6        Hritik Roshan                 War          Action
# 7        Kartik Aaryan      bhool boolya 2    Comedy Horror
# 8        Ranvir kapoor              Animan         Fantasy
# 9        shak ruk khan              Pathan          Action

# %%
cols = ["Year"] + [x for x in D2.columns if x != "Year"]
D2 [cols]
# Out:
#        Year             Name                Film            Gener  \
# 0      2016       Amir khan               Dangal       Biological
# Key 1  2017       VsrunDawan  Badhri ki dulaniya  Romantic comedy
# Key 2  2017      salmankhan     Tiger zindya he           Action
# 3      2018  Ayushman kurana            Padmawat      Historical
# 4      2018   Rajkummar rao                Stree           Horror
# 5      2019     Akshay Kumar          Good Newaz          Comedy
# 6      2019    Hritik Roshan                 War          Action
# 7      2022    Kartik Aaryan      bhool boolya 2    Comedy Horror
# 8      2022    Ranvir kapoor              Animan         Fantasy
# 9      2023    shak ruk khan              Pathan          Action
#
#        Box Office (NR Cross)  IMDB  Rank
# 0                       2024   9.2   1.0
# Key 1                    201   4.8   9.0
# Key 2                    565   8.0   4.0
# 3                        585   8.0   4.0
# ...
