# %%
import pandas as pd 
Data = pd.read_csv ("Movie.csv") 
Data.columns = Data.columns.str.strip () 
Data
# Out:
#              Actor                Film  Year            Gener  \
# 0    shak ruk khan              Pathan  2023          Action
# 1      salmankhan     Tiger zindya he   2017          Action
# 2       Amir khan               Dangal  2016       Biological
# 3    Ranvir kapoor              Animan  2022         Fantasy
# 4  Ayushman kurana            Padmawat  2018      Historical
# 5   Rajkummar rao                Stree  2018           Horror
# 6    Hritik Roshan                 War  2019          Action
# 7     Akshay Kumar          Good Newaz  2019          Comedy
# 8    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 9       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
#
#    Box Office (NR Cross)  IMDB
# 0                   1050   7.2
# 1                    565   8.0
# 2                   2024   9.2
# 3                    431   9.0
# 4                    585   8.0
# 5                    111   8.2
# 6                    180   7.6
# 7                    318   6.7
# ...

# %%
Data.sort_values ("Year")
# Out:
#              Actor                Film  Year            Gener  \
# 2       Amir khan               Dangal  2016       Biological
# 1      salmankhan     Tiger zindya he   2017          Action
# 9       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 4  Ayushman kurana            Padmawat  2018      Historical
# 5   Rajkummar rao                Stree  2018           Horror
# 6    Hritik Roshan                 War  2019          Action
# 7     Akshay Kumar          Good Newaz  2019          Comedy
# 3    Ranvir kapoor              Animan  2022         Fantasy
# 8    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 0    shak ruk khan              Pathan  2023          Action
#
#    Box Office (NR Cross)  IMDB
# 2                   2024   9.2
# 1                    565   8.0
# 9                    201   4.8
# 4                    585   8.0
# 5                    111   8.2
# 6                    180   7.6
# 7                    318   6.7
# 3                    431   9.0
# ...

# %%
Data.sort_values ("Box Office (NR Cross)" , ascending=False , inplace = True )

# %%
Data.sort_values (["Year","IMDB"] , ascending = False  ) 
Data
# Out:
#              Actor                Film  Year            Gener  \
# 0    shak ruk khan              Pathan  2023          Action
# 1    Ranvir kapoor              Animan  2022         Fantasy
# 2    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 3    Hritik Roshan                 War  2019          Action
# 4     Akshay Kumar          Good Newaz  2019          Comedy
# 5   Rajkummar rao                Stree  2018           Horror
# 6  Ayushman kurana            Padmawat  2018      Historical
# 7      salmankhan     Tiger zindya he   2017          Action
# 8       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 9       Amir khan               Dangal  2016       Biological
#
#    Box Office (NR Cross)  IMDB
# 0                   1050   7.2
# 1                    431   9.0
# 2                    166   7.7
# 3                    180   7.6
# 4                    318   6.7
# 5                    111   8.2
# 6                    585   8.0
# 7                    565   8.0
# ...

# %%
Data .reset_index ()
# Out:
#    index            Actor                Film  Year            Gener  \
# 0      0    shak ruk khan              Pathan  2023          Action
# 1      3    Ranvir kapoor              Animan  2022         Fantasy
# 2      8    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 3      6    Hritik Roshan                 War  2019          Action
# 4      7     Akshay Kumar          Good Newaz  2019          Comedy
# 5      5   Rajkummar rao                Stree  2018           Horror
# 6      4  Ayushman kurana            Padmawat  2018      Historical
# 7      1      salmankhan     Tiger zindya he   2017          Action
# 8      9       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 9      2       Amir khan               Dangal  2016       Biological
#
#    Box Office (NR Cross)  IMDB
# 0                   1050   7.2
# 1                    431   9.0
# 2                    166   7.7
# 3                    180   7.6
# 4                    318   6.7
# ...

# %%
Data.reset_index (drop = True)
# Out:
#              Actor                Film  Year            Gener  \
# 0    shak ruk khan              Pathan  2023          Action
# 1    Ranvir kapoor              Animan  2022         Fantasy
# 2    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 3    Hritik Roshan                 War  2019          Action
# 4     Akshay Kumar          Good Newaz  2019          Comedy
# 5   Rajkummar rao                Stree  2018           Horror
# 6  Ayushman kurana            Padmawat  2018      Historical
# 7      salmankhan     Tiger zindya he   2017          Action
# 8       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 9       Amir khan               Dangal  2016       Biological
#
#    Box Office (NR Cross)  IMDB
# 0                   1050   7.2
# 1                    431   9.0
# 2                    166   7.7
# 3                    180   7.6
# 4                    318   6.7
# 5                    111   8.2
# 6                    585   8.0
# 7                    565   8.0
# ...

# %%
Data.sort_index ()
# Out:
#              Actor                Film  Year            Gener  \
# 0    shak ruk khan              Pathan  2023          Action
# 1      salmankhan     Tiger zindya he   2017          Action
# 2       Amir khan               Dangal  2016       Biological
# 3    Ranvir kapoor              Animan  2022         Fantasy
# 4  Ayushman kurana            Padmawat  2018      Historical
# 5   Rajkummar rao                Stree  2018           Horror
# 6    Hritik Roshan                 War  2019          Action
# 7     Akshay Kumar          Good Newaz  2019          Comedy
# 8    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 9       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
#
#    Box Office (NR Cross)  IMDB
# 0                   1050   7.2
# 1                    565   8.0
# 2                   2024   9.2
# 3                    431   9.0
# 4                    585   8.0
# 5                    111   8.2
# 6                    180   7.6
# 7                    318   6.7
# ...

# %%
Data.reset_index (drop = True , inplace = True)

# %%
Data
# Out:
#              Actor                Film  Year            Gener  \
# 0       Amir khan               Dangal  2016       Biological
# 1    shak ruk khan              Pathan  2023          Action
# 2  Ayushman kurana            Padmawat  2018      Historical
# 3      salmankhan     Tiger zindya he   2017          Action
# 4    Ranvir kapoor              Animan  2022         Fantasy
# 5     Akshay Kumar          Good Newaz  2019          Comedy
# 6       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 7    Hritik Roshan                 War  2019          Action
# 8    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 9   Rajkummar rao                Stree  2018           Horror
#
#    Box Office (NR Cross)  IMDB
# 0                   2024   9.2
# 1                   1050   7.2
# 2                    585   8.0
# 3                    565   8.0
# 4                    431   9.0
# 5                    318   6.7
# 6                    201   4.8
# 7                    180   7.6
# ...

# %%
Data["Rank"] = Data ["Year"].rank ()

# %%
Data["Rank"] = Data ["Year"].rank (ascending = False , method = 'dense')

# %%
Data["Rank"] = Data ["Year"].rank (method = "dense")

# %%
Data.rename (columns = {"Actor" : "Name" , "Rank" : "Rating"} , inplace = True)

# %%
Data.rename (index = {0 : "Row 0"} , inplace = True)

# %%
Data
# Out:
#                   Name                Film  Year            Gener  \
# Row 0       Amir khan               Dangal  2016       Biological
# 1        shak ruk khan              Pathan  2023          Action
# 2      Ayushman kurana            Padmawat  2018      Historical
# 3          salmankhan     Tiger zindya he   2017          Action
# 4        Ranvir kapoor              Animan  2022         Fantasy
# 5         Akshay Kumar          Good Newaz  2019          Comedy
# 6           VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 7        Hritik Roshan                 War  2019          Action
# 8        Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 9       Rajkummar rao                Stree  2018           Horror
#
#        Box Office (NR Cross)  IMDB  Rating  Rank
# Row 0                   2024   9.2    10.0   6.0
# 1                       1050   7.2     1.0   1.0
# 2                        585   8.0     6.5   4.0
# ...

# %%
Data [["Name" , "Rating" , "Year"]]
# Out:
#                   Name  Rating  Year
# Row 0       Amir khan     10.0  2016
# 1        shak ruk khan     1.0  2023
# 2      Ayushman kurana     6.5  2018
# 3          salmankhan      8.5  2017
# 4        Ranvir kapoor     2.5  2022
# 5         Akshay Kumar     4.5  2019
# 6           VsrunDawan     8.5  2017
# 7        Hritik Roshan     4.5  2019
# 8        Kartik Aaryan     2.5  2022
# 9       Rajkummar rao      6.5  2018

# %%
Col = ["Rating"] + [x for x in Data.columns if x != "Rating"]
Data [Col]
# Out:
#        Rating             Name                Film  Year            Gener  \
# Row 0    10.0       Amir khan               Dangal  2016       Biological
# 1         1.0    shak ruk khan              Pathan  2023          Action
# 2         6.5  Ayushman kurana            Padmawat  2018      Historical
# 3         8.5      salmankhan     Tiger zindya he   2017          Action
# 4         2.5    Ranvir kapoor              Animan  2022         Fantasy
# 5         4.5     Akshay Kumar          Good Newaz  2019          Comedy
# 6         8.5       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 7         4.5    Hritik Roshan                 War  2019          Action
# 8         2.5    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 9         6.5   Rajkummar rao                Stree  2018           Horror
#
#        Box Office (NR Cross)  IMDB
# Row 0                   2024   9.2
# 1                       1050   7.2
# 2                        585   8.0
# ...
