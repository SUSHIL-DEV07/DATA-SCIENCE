# %%
import numpy as np 

A = np.array ([[1,2,3,4],
             [5,6,7,8]])
A
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
np.ones ([3,3])
np.zeros ([3,3]) 
np.eye (4)
np.full ([3,3] , 10 ) 
np.arange (1,10) 
np.linspace (1,5,5)
# Out:
# array([1., 2., 3., 4., 5.])

# %%
A.shape 
A.ndim
A.size 
A.dtype
# Out:
# dtype('int64')

# %%
A.astype ("str")
# Out:
# array([['1', '2', '3', '4'],
#        ['5', '6', '7', '8']], dtype='<U21')

# %%
A.reshape (4,2)
A.flatten ()
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])
