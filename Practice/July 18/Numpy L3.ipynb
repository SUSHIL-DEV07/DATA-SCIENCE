# %%
import numpy as np

# %%
A = np.array ([1,2,3,4,5])

# %%
B = A [:3]
B
# Out:
# array([1, 2, 3])

# %%
B[0] = 100

# %%
A # that return view
# Out:
# array([100,   2,   3,   4,   5])

# %%
C = A .copy ()

# %%
C[1] = 1000
A
C
# Out:
# array([ 100, 1000,    3,    4,    5])

# %%
ind = [2,3,4]
A [ind]
# Out:
# array([3, 4, 5])

# %%
A [A % 2 == 0]
# Out:
# array([100,   2,   4])

# %%
L1 = np.array ([1,2,3,4,5])
L2 = L1.copy ()
print ("Before")
print ("L1 = ", L1)
print ("L2 = " , L2)
print () 

L2 [0] = 1111
print ("After")
print ("L1 = ", L1)
print ("L2 = " , L2)
# Out:
# Before
# L1 =  [1 2 3 4 5]
# L2 =  [1 2 3 4 5]
#
# After
# L1 =  [1 2 3 4 5]
# L2 =  [1111    2    3    4    5]

# %%
ind = [2,3,4]
L1 [ind]
# Out:
# array([3, 4, 5])

# %%
cond = L1 % 2 == 0 
L1 [cond]
# Out:
# array([2, 4])

# %%
L1 = np.array ([1,2,3,4,5])
L1 = L2 
L2[0]= 1111
L1
L2
# Out:
# array([1111,    2,    3,    4,    5])

# %%
ind = [0,2,4]
L1 [ind]
# Out:
# array([1111,    3,    5])

# %%
cond = L1 % 2 == 0

# %%
L1[cond]
# Out:
# array([2, 4])
