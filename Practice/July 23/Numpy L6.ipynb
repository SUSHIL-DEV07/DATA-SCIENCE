# %%
import numpy as np

# %%
A = np.array ([[1,2,3] ,
              [4,5,6]]) 
A = A ** 2
A

B = np.array ([1,2,3]) 
B = B + [10,10,10]
B

A1 = np.array ([1,2,3])
A2 = np.array ([10,10,10])
A3 = A1 + A2
A3

B1 = np.array ([1,2,3])
B2 = np.array ([[10,10,10] ,[10,10,10]])
B3 = B1 + B2
B3
# Out:
# array([[11, 12, 13],
#        [11, 12, 13]])

# %%
Data = np.array([[10, 20, 30],
                 [15, 25, 35],
                 [20, 30, 40],
                 [25, 35, 45],
                 [30, 40, 50]])

mean = np.mean (Data)
std = np.std (Data)

normilized = ( Data - mean ) / std
normilized
# Out:
# array([[-1.8516402 , -0.9258201 ,  0.        ],
#        [-1.38873015, -0.46291005,  0.46291005],
#        [-0.9258201 ,  0.        ,  0.9258201 ],
#        [-0.46291005,  0.46291005,  1.38873015],
#        [ 0.        ,  0.9258201 ,  1.8516402 ]])
