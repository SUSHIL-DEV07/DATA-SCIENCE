# %% [markdown]
# # Lecture 1

# %%
import pandas as pd

# %% [markdown]
# # Lecture 2

# %%
D1 = pd.Series ([1,2] , index = ["A","B"]) 
D1
# Out:
# A    1
# B    2
# dtype: int64

# %%
D2 = pd.DataFrame ({
    "Name": ["a", "b","c"] ,
    "Age" : [34,34,32]
})
D2
# Out:
#   Name  Age
# 0    a   34
# 1    b   34
# 2    c   32

# %%
D2.columns
# Out:
# Index(['Name', 'Age'], dtype='object')

# %%
D2.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %% [markdown]
# # Lecture 3

# %%
D1 = pd.DataFrame ([["A" , 20],
                   ["B" , 30]] , columns = ["Name","Age"])
D1
# Out:
#   Name  Age
# 0    A   20
# 1    B   30

# %%
import numpy as np
A = np.array ([[2,5],
              [1,4]])
D2 = pd.DataFrame (A , columns = ["A","B"]) 
D2
# Out:
#    A  B
# 0  2  5
# 1  1  4

# %%
Data = pd.read_csv ("Movie.csv")

# %%
Data.head ()
# Out:
#             Actor               Film  Year         Gener  \
# 0    shak ruk khan            Pathan   2023      Action
# 1      salmankhan   Tiger zindya he    2017      Action
# 2       Amir khan             Dangal   2016   Biological
# 3    Ranvir kapoor            Animan   2022     Fantasy
# 4  Ayushman kurana          Padmawat   2018  Historical
#
#    Box Office (NR Cross)  IMDB
# 0                   1050   7.2
# 1                    565   8.0
# 2                   2024   9.2
# 3                    431   9.0
# 4                    585   8.0

# %%
Data.tail ()
# Out:
#            Actor                 Film  Year             Gener  \
# 5  Rajkummar rao                Stree   2018           Horror
# 6   Hritik Roshan                 War   2019          Action
# 7    Akshay Kumar          Good Newaz   2019          Comedy
# 8   Kartik Aaryan      bhool boolya 2   2022    Comedy Horror
# 9      VsrunDawan  Badhri ki dulaniya   2017  Romantic comedy
#
#    Box Office (NR Cross)  IMDB
# 5                    111   8.2
# 6                    180   7.6
# 7                    318   6.7
# 8                    166   7.7
# 9                    201   4.8

# %%
Data.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Actor                  10 non-null     object
#  1   Film                   10 non-null     object
#  2   Year                   10 non-null     int64
#  3   Gener                  10 non-null     object
#  4   Box Office (NR Cross)  10 non-null     int64
#  5   IMDB                   10 non-null     float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 612.0+ bytes

# %%
Data.describe ()
# Out:
#              Year   Box Office (NR Cross)       IMDB
# count    10.000000              10.000000  10.000000
# mean   2019.100000             563.100000   7.640000
# std       2.424413             585.877585   1.247397
# min    2016.000000             111.000000   4.800000
# 25%    2017.250000             185.250000   7.300000
# 50%    2018.500000             374.500000   7.850000
# 75%    2021.250000             580.000000   8.150000
# max    2023.000000            2024.000000   9.200000

# %%
Data.columns
# Out:
# Index(['Actor ', 'Film', 'Year ', 'Gener', 'Box Office (NR Cross)', 'IMDB'], dtype='object')

# %%
Data.shape
# Out:
# (10, 6)

# %% [markdown]
# # Lecture 4

# %%
Data.columns = Data.columns.str.strip () 
Data [["Actor" , "Film" , "Year" ]]
# Out:
#              Actor                Film  Year
# 0    shak ruk khan              Pathan  2023
# 1      salmankhan     Tiger zindya he   2017
# 2       Amir khan               Dangal  2016
# 3    Ranvir kapoor              Animan  2022
# 4  Ayushman kurana            Padmawat  2018
# 5   Rajkummar rao                Stree  2018
# 6    Hritik Roshan                 War  2019
# 7     Akshay Kumar          Good Newaz  2019
# 8    Kartik Aaryan      bhool boolya 2  2022
# 9       VsrunDawan  Badhri ki dulaniya  2017

# %%
Data.loc [0]
# Out:
# Actor                    shak ruk khan
# Film                            Pathan
# Year                              2023
# Gener                          Action
# Box Office (NR Cross)             1050
# IMDB                               7.2
# Name: 0, dtype: object

# %%
Data.loc [0,"Actor"]
# Out:
# 'shak ruk khan'

# %%
Data.loc [0 , ["Actor" , "Film"]]
# Out:
# Actor    shak ruk khan
# Film            Pathan
# Name: 0, dtype: object

# %%
Data.loc [0:3 , "Actor":"Year"]
# Out:
#            Actor              Film  Year
# 0  shak ruk khan            Pathan  2023
# 1    salmankhan   Tiger zindya he   2017
# 2     Amir khan             Dangal  2016
# 3  Ranvir kapoor            Animan  2022

# %%
Data.at [5 , "Film"]
# Out:
# 'Stree'

# %%
Data [Data["Year"] >= 2019 ]
# Out:
#            Actor            Film  Year          Gener  Box Office (NR Cross)  \
# 0  shak ruk khan          Pathan  2023        Action                    1050
# 3  Ranvir kapoor          Animan  2022       Fantasy                     431
# 6  Hritik Roshan             War  2019        Action                     180
# 7   Akshay Kumar      Good Newaz  2019        Comedy                     318
# 8  Kartik Aaryan  bhool boolya 2  2022  Comedy Horror                    166
#
#    IMDB
# 0   7.2
# 3   9.0
# 6   7.6
# 7   6.7
# 8   7.7

# %%
Data [(Data ["Year"] > 20) & (Data["IMDB"]> 8)]
# Out:
#             Actor    Film  Year       Gener  Box Office (NR Cross)  IMDB
# 2      Amir khan   Dangal  2016  Biological                   2024   9.2
# 3   Ranvir kapoor  Animan  2022    Fantasy                     431   9.0
# 5  Rajkummar rao    Stree  2018      Horror                    111   8.2

# %%
a = "Year"
b = 2017
Data.query (f"{a} > @b")
# Out:
#              Actor            Film  Year          Gener  \
# 0    shak ruk khan          Pathan  2023        Action
# 3    Ranvir kapoor          Animan  2022       Fantasy
# 4  Ayushman kurana        Padmawat  2018    Historical
# 5   Rajkummar rao            Stree  2018         Horror
# 6    Hritik Roshan             War  2019        Action
# 7     Akshay Kumar      Good Newaz  2019        Comedy
# 8    Kartik Aaryan  bhool boolya 2  2022  Comedy Horror
#
#    Box Office (NR Cross)  IMDB
# 0                   1050   7.2
# 3                    431   9.0
# 4                    585   8.0
# 5                    111   8.2
# 6                    180   7.6
# 7                    318   6.7
# 8                    166   7.7

# %% [markdown]
# # Lecture 5

# %%
D1 = pd.read_csv ("data_cleaning_sample.csv")

# %%
D1.isnull ().sum ()
# Out:
# Name         1
# Age          3
# City         0
# Gender       0
# Email        0
# Join Date    1
# dtype: int64

# %%
D1.dropna (axis =1 )
# Out:
#           City Gender              Email
# 0     New York      F  alice@example.com
# 1        Delhi      M    charlie@example
# 2  Los Angeles      M    bob@example.com
# 3        Delhi      M    charlie@example
# 4       Mumbai      M  david@example.com
# 5        Delhi      F     eve@domain.com
# 6     New York      F  alice@example.com
# 7     New York      F  alice@example.com
# 8        Delhi      M    charlie@example

# %%
D1.fillna (method = "bfill")
# Out:
# C:\Users\PRANAV\AppData\Local\Temp\ipykernel_3476\3086510020.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   D1.fillna (method = "bfill")
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie  30.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  22.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5    Alice  28.0        Delhi      F     eve@domain.com  01-05-2021
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
D1.dropna (inplace = True)

# %%
D1
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai      M  david@example.com  12-11-2019
# 6  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7  Alice  25.0     New York      F  alice@example.com  01-05-2021

# %%
D1.duplicated (["Name" , "Age"])
# Out:
# 0    False
# 2    False
# 4    False
# 6     True
# 7     True
# dtype: bool

# %%
D1.drop_duplicates ()
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai      M  david@example.com  12-11-2019

# %%
D1["Gender"].str.contains ("F" , case = False)
# Out:
# 0     True
# 2    False
# 4    False
# 6     True
# 7     True
# Name: Gender, dtype: bool

# %%
D1["Age"] = D1["Age"].astype (int)

# %%
D1["Date"] = pd.to_datetime (D1["Join Date"] ,
                            format = "%d-%m-%Y" ,
                            errors = "coerce")

# %%
D1
# Out:
#     Name  Age         City Gender              Email   Join Date       Date
# 0  Alice   25     New York      F  alice@example.com  01-05-2021 2021-05-01
# 2    Bob   30  Los Angeles      M    bob@example.com  15-06-2020 2020-06-15
# 4  David   22       Mumbai      M  david@example.com  12-11-2019 2019-11-12
# 6  Alice   25     New York      F  alice@example.com  01-05-2021 2021-05-01
# 7  Alice   25     New York      F  alice@example.com  01-05-2021 2021-05-01

# %%
D1["Age Catagory"] = D1["Age"].apply (lambda x : "Adult" if x > 25 else "Minor")

# %%
D1["Gender"] = D1["Gender"]. map ({
    "F" : "Female",
    "M" : "Male"
}) 
D1
# Out:
#     Name  Age         City  Gender              Email   Join Date       Date  \
# 0  Alice   25     New York  Female  alice@example.com  01-05-2021 2021-05-01
# 2    Bob   30  Los Angeles    Male    bob@example.com  15-06-2020 2020-06-15
# 4  David   22       Mumbai    Male  david@example.com  12-11-2019 2019-11-12
# 6  Alice   25     New York  Female  alice@example.com  01-05-2021 2021-05-01
# 7  Alice   25     New York  Female  alice@example.com  01-05-2021 2021-05-01
#
#   Age Catagory
# 0        Minor
# 2        Adult
# 4        Minor
# 6        Minor
# 7        Minor

# %%
D1["City"] = D1 ["City"].replace ({
    "New York" : "York",
    "Mumbai" : "Navi Mumbai"
 }) 
D1
# Out:
#     Name  Age         City  Gender              Email   Join Date       Date  \
# 0  Alice   25         York  Female  alice@example.com  01-05-2021 2021-05-01
# 2    Bob   30  Los Angeles    Male    bob@example.com  15-06-2020 2020-06-15
# 4  David   22  Navi Mumbai    Male  david@example.com  12-11-2019 2019-11-12
# 6  Alice   25         York  Female  alice@example.com  01-05-2021 2021-05-01
# 7  Alice   25         York  Female  alice@example.com  01-05-2021 2021-05-01
#
#   Age Catagory
# 0        Minor
# 2        Adult
# 4        Minor
# 6        Minor
# 7        Minor

# %% [markdown]
# # Lecture 6

# %%
Data = pd.read_csv ("Movie.csv")
Data.columns = Data.columns.str.strip ()

# %%
Data.sort_values (["Year" , "IMDB"],ascending = False , inplace = True)

# %%
Data.sort_index ()
# Out:
#              Actor                Film  Year            Gener  \
# 0    shak ruk khan              Pathan  2023          Action
# 1      salmankhan     Tiger zindya he   2017          Action
# 2       Amir khan               Dangal  2016       Biological
# 3    Ranvir kapoor              Animan  2022         Fantasy
# 4  Ayushman kurana            Padmawat  2018      Historical
# 5   Rajkummar rao                Stree  2018           Horror
# 6    Hritik Roshan                 War  2019          Action
# 7     Akshay Kumar          Good Newaz  2019          Comedy
# 8    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 9       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
#
#    Box Office (NR Cross)  IMDB
# 0                   1050   7.2
# 1                    565   8.0
# 2                   2024   9.2
# 3                    431   9.0
# 4                    585   8.0
# 5                    111   8.2
# 6                    180   7.6
# 7                    318   6.7
# ...

# %%
Data.reset_index (drop = True , inplace = True)

# %%
Data
# Out:
#              Actor                Film  Year            Gener  \
# 0    shak ruk khan              Pathan  2023          Action
# 1    Ranvir kapoor              Animan  2022         Fantasy
# 2    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 3    Hritik Roshan                 War  2019          Action
# 4     Akshay Kumar          Good Newaz  2019          Comedy
# 5   Rajkummar rao                Stree  2018           Horror
# 6  Ayushman kurana            Padmawat  2018      Historical
# 7      salmankhan     Tiger zindya he   2017          Action
# 8       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 9       Amir khan               Dangal  2016       Biological
#
#    Box Office (NR Cross)  IMDB
# 0                   1050   7.2
# 1                    431   9.0
# 2                    166   7.7
# 3                    180   7.6
# 4                    318   6.7
# 5                    111   8.2
# 6                    585   8.0
# 7                    565   8.0
# ...

# %%
Data ["Rank"] = Data["Year"].rank (ascending = False , method = 'dense')

# %%
Data
# Out:
#              Actor                Film  Year            Gener  \
# 0    shak ruk khan              Pathan  2023          Action
# 1    Ranvir kapoor              Animan  2022         Fantasy
# 2    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 3    Hritik Roshan                 War  2019          Action
# 4     Akshay Kumar          Good Newaz  2019          Comedy
# 5   Rajkummar rao                Stree  2018           Horror
# 6  Ayushman kurana            Padmawat  2018      Historical
# 7      salmankhan     Tiger zindya he   2017          Action
# 8       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 9       Amir khan               Dangal  2016       Biological
#
#    Box Office (NR Cross)  IMDB  Rank
# 0                   1050   7.2   1.0
# 1                    431   9.0   2.0
# 2                    166   7.7   2.0
# 3                    180   7.6   3.0
# 4                    318   6.7   3.0
# 5                    111   8.2   4.0
# ...

# %%
Data.rename (columns = {"Actor": "name"} , inplace = True)

# %%
Data.rename (index = {0 : "Row 1"} , inplace = True)

# %%
Data
# Out:
#                   name                Film  Year            Gener  \
# Row 1    shak ruk khan              Pathan  2023          Action
# 1        Ranvir kapoor              Animan  2022         Fantasy
# 2        Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 3        Hritik Roshan                 War  2019          Action
# 4         Akshay Kumar          Good Newaz  2019          Comedy
# 5       Rajkummar rao                Stree  2018           Horror
# 6      Ayushman kurana            Padmawat  2018      Historical
# 7          salmankhan     Tiger zindya he   2017          Action
# 8           VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 9           Amir khan               Dangal  2016       Biological
#
#        Box Office (NR Cross)  IMDB  Rank
# Row 1                   1050   7.2   1.0
# 1                        431   9.0   2.0
# 2                        166   7.7   2.0
# 3                        180   7.6   3.0
# ...

# %%
Data [["Gener" , "name" , "Rank"]]
# Out:
#                  Gener             name  Rank
# Row 1          Action     shak ruk khan   1.0
# 1             Fantasy     Ranvir kapoor   2.0
# 2        Comedy Horror    Kartik Aaryan   2.0
# 3              Action     Hritik Roshan   3.0
# 4              Comedy      Akshay Kumar   3.0
# 5               Horror   Rajkummar rao    4.0
# 6          Historical   Ayushman kurana   4.0
# 7              Action       salmankhan    5.0
# 8      Romantic comedy       VsrunDawan   5.0
# 9           Biological       Amir khan    6.0

# %% [markdown]
# # Lecture 7

# %%
import pandas as pd

# Sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Math': [85, 78, 92],
    'Science': [90, 82, 89],
    'English': [88, 85, 94]
}

Data = pd.DataFrame(data)

# Display the DataFrame
print(Data)
# Out:
#       Name  Math  Science  English
# 0    Alice    85       90       88
# 1      Bob    78       82       85
# 2  Charlie    92       89       94

# %%
Data =Data.melt (id_vars = ["Name"] ,value_vars = ['Math','Science','English'] , var_name ="Subject" , value_name = "Score" )

# %%
Data.pivot (index = "Name" , columns = "Subject" , values = "Score")
# Out:
# Subject  English  Math  Science
# Name
# Alice         88    85       90
# Bob           85    78       82
# Charlie       94    92       89

# %%
Data
# Out:
#       Name  Subject  Score
# 0    Alice     Math     85
# 1      Bob     Math     78
# 2  Charlie     Math     92
# 3    Alice  Science     90
# 4      Bob  Science     82
# 5  Charlie  Science     89
# 6    Alice  English     88
# 7      Bob  English     85
# 8  Charlie  English     94

# %%
Data.loc[9] = ["Alice" , "Math", 80]

# %%
Data.pivot_table (index = "Name" , columns = "Subject" ,values = "Score" ,aggfunc = "max")
# Out:
# Subject  English  Math  Science
# Name
# Alice         88    85       90
# Bob           85    78       82
# Charlie       94    92       89

# %% [markdown]
# # Lecture 8

# %%
Data = pd.DataFrame({
    "Department": ["HR", "HR", "IT", "IT", "Marketing", "Marketing", "Sales", "Sales"],
    "Team": ["A", "A", "B", "B", "C", "C", "D", "D"],
    "Gender": ["M", "F", "M", "F", "M", "F", "M", "F"],
    "Salary": [85, 90, 78, 85, 92, 88, 75, 80],
    "Age": [23, 25, 30, 22, 28, 26, 21, 27],
    "JoinDate": pd.to_datetime([
        "2020-01-10", "2020-02-15", "2021-03-20", "2021-04-10",
        "2020-05-30", "2020-06-25", "2021-07-15", "2021-08-01"
    ])
})

# %%
Data
# Out:
#   Department Team Gender  Salary  Age   JoinDate
# 0         HR    A      M      85   23 2020-01-10
# 1         HR    A      F      90   25 2020-02-15
# 2         IT    B      M      78   30 2021-03-20
# 3         IT    B      F      85   22 2021-04-10
# 4  Marketing    C      M      92   28 2020-05-30
# 5  Marketing    C      F      88   26 2020-06-25
# 6      Sales    D      M      75   21 2021-07-15
# 7      Sales    D      F      80   27 2021-08-01

# %%
Data.groupby (["Department" , "Gender"] )["Salary"].max ()
# Out:
# Department  Gender
# HR          F         90
#             M         85
# IT          F         85
#             M         78
# Marketing   F         88
#             M         92
# Sales       F         80
#             M         75
# Name: Salary, dtype: int64

# %%
Data.groupby ("Department") ["Salary"] .agg (["mean" ,"max" , "min"]
                                            )
# Out:
#             mean  max  min
# Department
# HR          87.5   90   85
# IT          81.5   85   78
# Marketing   90.0   92   88
# Sales       77.5   80   75

# %%
Data.groupby ("Team") ["Salary"] .agg (Avg_sal = "mean" ,
                                      Max_sal = "max")
# Out:
#       Avg_sal  Max_sal
# Team
# A        87.5       90
# B        81.5       85
# C        90.0       92
# D        77.5       80

# %%
Data.groupby ("Team").agg ({
    "Salary": "mean",
    "Age" : "max"
})
# Out:
#       Salary  Age
# Team
# A       87.5   25
# B       81.5   30
# C       90.0   28
# D       77.5   27

# %%
Data["Rank"] = Data.groupby ("Department") ['Age'].transform ("max")

# %%
Data
# Out:
#   Department Team Gender  Salary  Age   JoinDate  Rank
# 0         HR    A      M      85   23 2020-01-10    25
# 1         HR    A      F      90   25 2020-02-15    25
# 2         IT    B      M      78   30 2021-03-20    30
# 3         IT    B      F      85   22 2021-04-10    30
# 4  Marketing    C      M      92   28 2020-05-30    28
# 5  Marketing    C      F      88   26 2020-06-25    28
# 6      Sales    D      M      75   21 2021-07-15    27
# 7      Sales    D      F      80   27 2021-08-01    27

# %%
Data .groupby("Team").filter (lambda x : x["Salary"].max () >90)
# Out:
#   Department Team Gender  Salary  Age   JoinDate  Rank
# 4  Marketing    C      M      92   28 2020-05-30    28
# 5  Marketing    C      F      88   26 2020-06-25    28

# %% [markdown]
# # Lecture 9

# %%
employees = pd.DataFrame({
    "EmpID": [1, 2, 3],
    "Name": ["Alice", "Bob", "Charlie"],
    "DeptID": [10, 20, 30]
})

departments = pd.DataFrame({
    "DeptID": [10, 20, 40],
    "DeptName": ["HR", "Engineering", "Marketing"]
})

# %%
employees
# Out:
#    EmpID     Name  DeptID
# 0      1    Alice      10
# 1      2      Bob      20
# 2      3  Charlie      30

# %%
departments
# Out:
#    DeptID     DeptName
# 0      10           HR
# 1      20  Engineering
# 2      40    Marketing

# %%
pd.merge (employees , departments , on = "DeptID" , how = "outer")
# Out:
#    EmpID     Name  DeptID     DeptName
# 0    1.0    Alice      10           HR
# 1    2.0      Bob      20  Engineering
# 2    3.0  Charlie      30          NaN
# 3    NaN      NaN      40    Marketing

# %%
df1 = pd.DataFrame({"Name": ["Alice", "Bob"]})
df2 = pd.DataFrame({"Name": ["Charlie", "David"]})

pd.concat([df1, df2])
# Out:
#       Name
# 0    Alice
# 1      Bob
# 0  Charlie
# 1    David

# %%
pd.concat ([df1,df2] , axis = 1 )
# Out:
#     Name     Name
# 0  Alice  Charlie
# 1    Bob    David

# %%
D1
# Out:
#     Name  Age         City  Gender              Email   Join Date       Date  \
# 0  Alice   25         York  Female  alice@example.com  01-05-2021 2021-05-01
# 2    Bob   30  Los Angeles    Male    bob@example.com  15-06-2020 2020-06-15
# 4  David   22  Navi Mumbai    Male  david@example.com  12-11-2019 2019-11-12
# 6  Alice   25         York  Female  alice@example.com  01-05-2021 2021-05-01
# 7  Alice   25         York  Female  alice@example.com  01-05-2021 2021-05-01
#
#   Age Catagory
# 0        Minor
# 2        Adult
# 4        Minor
# 6        Minor
# 7        Minor

# %% [markdown]
# # Lecture 10

# %%
D1.to_excel ("A.xlsx" , sheet_name = "S1")

# %%
D2 = pd.read_excel ("A.xlsx" , sheet_name = "S1")

# %%
with pd.ExcelWriter ("B.xlsx")  as E :
    D1.to_excel (E , sheet_name = "S1")
