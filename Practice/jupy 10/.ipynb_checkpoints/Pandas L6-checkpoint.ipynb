# %%
import pandas as pd

# %%
Data = pd.read_csv ("Movie.csv")

# %%
Data.columns = Data.columns.str.strip ()

# %%
Data.sort_values (["Year" ,"IMDB"] , ascending = False , inplace = True)

# %%
Data.sort_index ()
# Out:
#              Actor                Film  Year            Gener  \
# 0    shak ruk khan              Pathan  2023          Action
# 1      salmankhan     Tiger zindya he   2017          Action
# 2       Amir khan               Dangal  2016       Biological
# 3    Ranvir kapoor              Animan  2022         Fantasy
# 4  Ayushman kurana            Padmawat  2018      Historical
# 5   Rajkummar rao                Stree  2018           Horror
# 6    Hritik Roshan                 War  2019          Action
# 7     Akshay Kumar          Good Newaz  2019          Comedy
# 8    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 9       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
#
#    Box Office (NR Cross)  IMDB
# 0                   1050   7.2
# 1                    565   8.0
# 2                   2024   9.2
# 3                    431   9.0
# 4                    585   8.0
# 5                    111   8.2
# 6                    180   7.6
# 7                    318   6.7
# ...

# %%
Data
# Out:
#              Actor                Film  Year            Gener  \
# 0    shak ruk khan              Pathan  2023          Action
# 3    Ranvir kapoor              Animan  2022         Fantasy
# 8    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 6    Hritik Roshan                 War  2019          Action
# 7     Akshay Kumar          Good Newaz  2019          Comedy
# 5   Rajkummar rao                Stree  2018           Horror
# 4  Ayushman kurana            Padmawat  2018      Historical
# 1      salmankhan     Tiger zindya he   2017          Action
# 9       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 2       Amir khan               Dangal  2016       Biological
#
#    Box Office (NR Cross)  IMDB
# 0                   1050   7.2
# 3                    431   9.0
# 8                    166   7.7
# 6                    180   7.6
# 7                    318   6.7
# 5                    111   8.2
# 4                    585   8.0
# 1                    565   8.0
# ...

# %%
Data.reset_index (drop = True ,  inplace= True)

# %%
Data
# Out:
#              Actor                Film  Year            Gener  \
# 0    shak ruk khan              Pathan  2023          Action
# 1    Ranvir kapoor              Animan  2022         Fantasy
# 2    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 3    Hritik Roshan                 War  2019          Action
# 4     Akshay Kumar          Good Newaz  2019          Comedy
# 5   Rajkummar rao                Stree  2018           Horror
# 6  Ayushman kurana            Padmawat  2018      Historical
# 7      salmankhan     Tiger zindya he   2017          Action
# 8       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 9       Amir khan               Dangal  2016       Biological
#
#    Box Office (NR Cross)  IMDB
# 0                   1050   7.2
# 1                    431   9.0
# 2                    166   7.7
# 3                    180   7.6
# 4                    318   6.7
# 5                    111   8.2
# 6                    585   8.0
# 7                    565   8.0
# ...

# %%
Data["Rank"] = Data["IMDB"].rank ()

# %%
Data["Rank"] = Data ["IMDB"].rank (ascending=False , method = "dense")

# %%
Data
# Out:
#              Actor                Film  Year            Gener  \
# 0    shak ruk khan              Pathan  2023          Action
# 1    Ranvir kapoor              Animan  2022         Fantasy
# 2    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 3    Hritik Roshan                 War  2019          Action
# 4     Akshay Kumar          Good Newaz  2019          Comedy
# 5   Rajkummar rao                Stree  2018           Horror
# 6  Ayushman kurana            Padmawat  2018      Historical
# 7      salmankhan     Tiger zindya he   2017          Action
# 8       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 9       Amir khan               Dangal  2016       Biological
#
#    Box Office (NR Cross)  IMDB  Rank
# 0                   1050   7.2   7.0
# 1                    431   9.0   2.0
# 2                    166   7.7   5.0
# 3                    180   7.6   6.0
# 4                    318   6.7   8.0
# 5                    111   8.2   3.0
# ...

# %%
Data.rename (columns = {"Actor" : "Name"}, inplace = True)

# %%
Data.rename (index = {0 : "Key 0"} , inplace = True)

# %%
Data
# Out:
#                   Name                Film  Year            Gener  \
# Key 0    shak ruk khan              Pathan  2023          Action
# 1        Ranvir kapoor              Animan  2022         Fantasy
# 2        Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 3        Hritik Roshan                 War  2019          Action
# 4         Akshay Kumar          Good Newaz  2019          Comedy
# 5       Rajkummar rao                Stree  2018           Horror
# 6      Ayushman kurana            Padmawat  2018      Historical
# 7          salmankhan     Tiger zindya he   2017          Action
# 8           VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 9           Amir khan               Dangal  2016       Biological
#
#        Box Office (NR Cross)  IMDB  Rank
# Key 0                   1050   7.2   7.0
# 1                        431   9.0   2.0
# 2                        166   7.7   5.0
# 3                        180   7.6   6.0
# ...

# %%
Data [["Name" , "Year","IMDB"]]
# Out:
#                   Name  Year  IMDB
# Key 0    shak ruk khan  2023   7.2
# 1        Ranvir kapoor  2022   9.0
# 2        Kartik Aaryan  2022   7.7
# 3        Hritik Roshan  2019   7.6
# 4         Akshay Kumar  2019   6.7
# 5       Rajkummar rao   2018   8.2
# 6      Ayushman kurana  2018   8.0
# 7          salmankhan   2017   8.0
# 8           VsrunDawan  2017   4.8
# 9           Amir khan   2016   9.2

# %%
D = ["Rank"] + [x for x in Data.columns if x != "Rank"]

# %%
Data [D]
# Out:
#        Rank             Name                Film  Year            Gener  \
# Key 0   7.0    shak ruk khan              Pathan  2023          Action
# 1       2.0    Ranvir kapoor              Animan  2022         Fantasy
# 2       5.0    Kartik Aaryan      bhool boolya 2  2022    Comedy Horror
# 3       6.0    Hritik Roshan                 War  2019          Action
# 4       8.0     Akshay Kumar          Good Newaz  2019          Comedy
# 5       3.0   Rajkummar rao                Stree  2018           Horror
# 6       4.0  Ayushman kurana            Padmawat  2018      Historical
# 7       4.0      salmankhan     Tiger zindya he   2017          Action
# 8       9.0       VsrunDawan  Badhri ki dulaniya  2017  Romantic comedy
# 9       1.0       Amir khan               Dangal  2016       Biological
#
#        Box Office (NR Cross)  IMDB
# Key 0                   1050   7.2
# 1                        431   9.0
# 2                        166   7.7
# 3                        180   7.6
# ...
