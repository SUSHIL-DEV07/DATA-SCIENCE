# %% [markdown]
# # String Creation

# %%
Str1 = "String"
Str2 = 'String'
Str3 = '''String''' # Multi line String

# %% [markdown]
# # String Function

# %%
len (Str1)
# Out:
# 6

# %%
Str1.lower ()
# Out:
# 'string'

# %%
Str1.upper ()
# Out:
# 'STRING'

# %%
Str1.replace ("S" ,"A")
# Out:
# 'Atring'

# %%
Str1.count("S")
# Out:
# 1

# %%
Str1.find ("S")
# Out:
# 0

# %%
" name ".strip ()
# Out:
# ' name'

# %%
Str1.startswith ("s")
# Out:
# False

# %%
Str1.endswith ("g")
# Out:
# True

# %% [markdown]
# # ACCESS STRING

# %%
Str = "String"

# %%
Str[0]
# Out:
# 'S'

# %%
Str[0:5] #last access can not print
# Out:
# 'Strin'

# %%
Str[0:6]
# Out:
# 'String'

# %%
Str[::-1]
# Out:
# 'gnirtS'

# %%
Str[-6:-1]
# Out:
# 'Strin'

# %%
Str[-6: : ]
# Out:
# 'String'

# %%
Str[-1: : -1]
# Out:
# 'gnirtS'
