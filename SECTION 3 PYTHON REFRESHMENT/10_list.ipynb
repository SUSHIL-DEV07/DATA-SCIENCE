# %% [markdown]
# # List

# %%
L = [1,2,3,4,5,6,7,8,9]
print(L)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# # List Methods

# %%
L1 = [1,2,3,4]

# %%
L1.append (5)
L1
# Out:
# [1, 2, 3, 4, 5]

# %%
L1.extend ([6,7])
L1
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
L1.remove (7) 
L1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
L1.insert (1,100)
L1
# Out:
# [1, 100, 2, 3, 4, 5, 6]

# %%
L1.index (1)
# Out:
# 0

# %%
L1.count(6)
# Out:
# 1

# %%
L1.pop (1)
# Out:
# 100

# %%
L1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
L1.sort (reverse=True)
print (L1)
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
sorted (L1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
L1
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
L2 = L1.copy () 
L2
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
L1.clear () 
L1
# Out:
# []

# %%
del L1
