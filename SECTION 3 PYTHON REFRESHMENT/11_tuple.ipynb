# %% [markdown]
# # TUPLES

# %%
T1 = (1,2,3,4)

# %%
print (type (T1) )
print (T1)
# Out:
# <class 'tuple'>
# ()

# %%
T1 = () # Empty List

# %%
T2 = (19)
print (type (T2))
# Out:
# <class 'int'>

# %%
T2 = (19,)
print (type (T2))
# Out:
# <class 'tuple'>

# %% [markdown]
# # TUPLE METHODS

# %%
T1 = (1,2,3,4,5)

# %%
len (T1)
# Out:
# 5

# %%
T1.index (3)
# Out:
# 2

# %%
T1.count (2)
# Out:
# 1

# %% [markdown]
# # TUPLE UNPACKING

# %%
T1 = ( "Sushil" , 24 , "CS" )

# %%
name , rollno , branch = T1

# %%
print (name , rollno , branch)
# Out:
# Sushil 24 CS

# %%
name , *other = T1

# %%
print (name , *other)
# Out:
# Sushil 24 CS

# %%
other
# Out:
# [24, 'CS']

# %%
T2 = [1,2,3,4,5]
one , *other , last = T2
other
# Out:
# [2, 3, 4]

# %%
*Other , end = T2

# %%
Other
# Out:
# [1, 2, 3, 4]
