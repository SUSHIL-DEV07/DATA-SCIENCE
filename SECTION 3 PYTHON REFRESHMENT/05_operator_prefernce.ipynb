# %% [markdown]
# # Operator Preference

# %% [markdown]
# ### PEMDAS

# %% [markdown]
#
#     P = parameter
#     E = Expontial
#     M = Multiplication
#     D = Division
#     A = Addition
#     S = Subtraction

# %%
Result = 10 + 20 * 5
Result
# Out:
# 110

# %%
Result = 2 ** 2 ** 2 # only expomntal : right to left
Result
# Out:
# 16

# %%
Result = (2 + 4) / 2
Result
# Out:
# 3.0

# %% [markdown]
# # Example

# %%
45 + 40 / 20 * 10 /5 ** 2
# Out:
# 45.8

# %%
45 + 40 / 20 * 10 / 25
# Out:
# 45.8

# %%
45 + 2.0 * 10 / 25
# Out:
# 45.8

# %%
45 + 20 /25
# Out:
# 45.8

# %%
45 + 0.8
# Out:
# 45.8
