# %% [markdown]
# # DICT

# %% [markdown]
# ## 3.7 Update Dict is Unordered

# %%
D1 = {} # Empty Dict
print (type (D1))
# Out:
# <class 'dict'>

# %%
D1 = { "Sushil" : 99 ,
     "Ramesh" : 98 ,
     "Suresh" : 95 }
D1
# Out:
# {'Sushil': 99, 'Ramesh': 98, 'Suresh': 95}
