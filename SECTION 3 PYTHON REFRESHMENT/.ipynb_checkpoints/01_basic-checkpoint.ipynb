# %% [markdown]
# # Variable

# %%
a = 10 
b = 3.14
c = "String"
d = True

# %%
print ("Hellow world ")
# Out:
# Hellow world

# %%
type (a)
# Out:
# int

# %%
a = "1111"
b = "1111"

# %%
a + b
# Out:
# '11111111'

# %%
int (a) + int (b)
# Out:
# 2222

# %%
# single line Comment

# %%
'''
Multi
line 
Comment 
'''
# Out:
# '\nMulti\nline \nComment \n'
