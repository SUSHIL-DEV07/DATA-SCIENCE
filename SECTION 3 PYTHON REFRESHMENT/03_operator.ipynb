# %% [markdown]
# # Arithmetioc operator

# %%
a = 10 
b = 20

# %%
a + b
# Out:
# 10

# %%
a - b
# Out:
# -10

# %%
a * b
# Out:
# 200

# %%
a / b
# Out:
# 0.5

# %%
a // b
# Out:
# 0

# %%
a ** b
# Out:
# 100000000000000000000

# %%
a % b
# Out:
# 10

# %% [markdown]
# # Comparision Operator

# %%
a = 10 
b = 20

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a >= b
# Out:
# False

# %%
a <= b
# Out:
# True

# %% [markdown]
# # Logical Operator

# %%
not True
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True and False
# Out:
# False

# %% [markdown]
# # Bitwise Operator

# %%
a = 5
b = 1

# %%
a & b
# Out:
# 1

# %%
a | b
# Out:
# 5

# %% [markdown]
# # Assignment operator

# %%
a = 5

# %%
a += 5
a
# Out:
# 15

# %%
a -= 5
a
# Out:
# 5

# %%
a *= 5
a
# Out:
# 25

# %%
a /= 5
a
# Out:
# 5.0

# %% [markdown]
# # Membership Operator

# %%
L1 = [1,2,3]
L2 = [4,5,6]

# %%
1 in L1
# Out:
# True

# %%
1 not in L1
# Out:
# False

# %%
L1 is L2
# Out:
# False

# %%
L1 is not L2
# Out:
# True
