# %% [markdown]
# # DICT

# %% [markdown]
# ## 3.7 Update Dict is Unordered

# %%
D1 = {} # Empty Dict
print (type (D1))
# Out:
# <class 'dict'>

# %%
D1 = { "Sushil" : 99 ,
     "Ramesh" : 98 ,
     "Suresh" : 95 }
D1
# Out:
# {'Sushil': 99, 'Ramesh': 98, 'Suresh': 95}

# %%
D2 = dict ( name = "Sushil", age = 20 , city = "Parbhani")
D2
# Out:
# {'name': 'Sushil', 'age': 20, 'city': 'Parbhani'}

# %% [markdown]
# # Access Dict element

# %%
D1
# Out:
# {'Sushil': 99, 'Ramesh': 98, 'Suresh': 95}

# %%
D1 ["Sushil"]
# Out:
# 99

# %%
D1.get ("Ramesh")
# Out:
# 98

# %%
D1.get ("Mukesh") # Return none

# %%
D1.get ("Mukesh",0) # Return none
# Out:
# 0

# %% [markdown]
# # DICT METHODS

# %%
D1
# Out:
# {'Sushil': 99, 'Ramesh': 98, 'Suresh': 95}

# %%
D1.keys()
# Out:
# dict_keys(['Sushil', 'Ramesh', 'Suresh'])

# %%
D1.values()
# Out:
# dict_values([99, 98, 95])

# %%
D1.items ()
# Out:
# dict_items([('Sushil', 99), ('Ramesh', 98), ('Suresh', 95)])

# %%
D1.pop ("Sushil")
# Out:
# 99

# %%
D1.popitem ()
# Out:
# ('Suresh', 95)

# %%
D1
# Out:
# {'Ramesh': 98}

# %%
D1.update ({"Mahesh" : 20 , "Ganesh" : 30 }) 
D1
# Out:
# {'Ramesh': 98, 'Mahesh': 20, 'Ganesh': 30}

# %%
D1.setdefault ("Ramesh" , 10 )
# Out:
# 98

# %%
D1["Ramesh"]
# Out:
# 98

# %%
D1.pop ("Ramesh")
# Out:
# 98

# %%
D2 = D1.copy ()
D2
# Out:
# {'Mahesh': 20, 'Ganesh': 30}

# %%
D1.clear ()

# %%
D1
# Out:
# {}

# %% [markdown]
# # DICT ITERATE IN LOOP

# %%
for i , j  in D1.items():
    print (i, " : ",j)
# Out:
# Sushil  :  99
# Ramesh  :  98
# Suresh  :  95
